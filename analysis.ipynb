# %% [markdown]
# Necessary (external) libraries:
# - jiwer
# - python-docx

# %%
import jiwer
#import batchalign
import os
import pathlib
from docx import Document
import re
import pandas as pd

#pd.set_option("display.max_columns", 50) 
#pd.set_option("display.max_rows", 50)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Setting up the Paths

# %%
#setting up the paths

path = pathlib.Path().resolve()

#path to the directory with the Batchalign transcriptions
hypothesis_path = path / "transkrypty_czyszczonych_nagrań"

#path to the directory with the human transcriptions
reference_path = path / "czyszczone_transkrypcje"

#path to the directory where the copy of the human transcriptions is saved
reference_path_copy = path / "czyszczone_transkrypcje_copy"

#path to the directory where the copy of the Batchalign transcriptions is saved
hypothesis_path_copy = path / "transkrypty_czyszczonych_nagrań_copy"

# %% [markdown]
# #### Script for reseting the files inside the reference_path

# %%
# #ONLY RUN THIS SCRIPT IF YOU WANT TO RESET THE REFERENCE PATH

# # to unncomment the code, select it and press Ctrl + / (or Cmd + / on Mac) 
# # This script will delete all files in the reference_path and copy files from reference_path_copy to reference_path

# import shutil

# # 1. Delete all files from reference_path
# for file in reference_path.iterdir():
#     if file.is_file():
#         file.unlink()

# # 2. Copy all files from reference_path_copy to reference_path
# for file in reference_path_copy.iterdir():
#     if file.is_file():
#         target = reference_path / file.name
#         shutil.copy2(file, target)

# %% [markdown]
# #### Script for reseting the files inside the hypothesis_path

# %%
# #ONLY RUN THIS SCRIPT IF YOU WANT TO 'RESET' THE HYPOTHESIS PATH

# # to unncomment the code, select it and press Ctrl + / (or Cmd + / on Mac) 
# # This script will delete all files in the hypothesis_path and copy files from hypothesis_path_copy to hypothesis_path

# import shutil

# # 1. Delete all files from hypothesis_path
# for file in hypothesis_path.iterdir():
#     if file.is_file():
#         file.unlink()

# # 2. Copy all files from hypothesis_path_copy to hypothesis_path
# for file in hypothesis_path_copy.iterdir():
#     if file.is_file():
#         target = hypothesis_path / file.name
#         shutil.copy2(file, target)

# %% [markdown]
# ## Preprocessing the reference_path

# %% [markdown]
# ### Converting the reference files to .txt

# %%
#converting all files in the reference_path to a .txt format

def convert_docx_or_cha_to_txt(file_path):
    """
    
    # !!!!!
    Remember to have the backup of the original files before running this function, as it will delete the original files after conversion
    # !!!!! 

    Converts .docx or .cha files to .txt format and deletes the original file.

    """
    if file_path.suffix.lower() == '.docx':
        new_file_path = file_path.with_suffix('.txt')
        try:
            doc = Document(file_path)
            content = "\n".join([para.text for para in doc.paragraphs])
            with open(new_file_path, 'w', encoding='utf-8') as f:
                f.write(content)
            os.remove(file_path)
            print(f"Converted and removed: {file_path}")
            return new_file_path
        except Exception as e:
            print(f"Error converting {file_path}: {e}")
            return file_path
        
    elif file_path.suffix.lower() == '.cha':
        new_file_path = file_path.with_suffix('.txt')
        try:
            with open(file_path, 'r', encoding='utf-8') as f_in:
                content = f_in.read()
            with open(new_file_path, 'w', encoding='utf-8') as f_out:
                f_out.write(content)
            os.remove(file_path)
            print(f"Converted and removed: {file_path}")
            return new_file_path
        except Exception as e:
            print(f"Error converting {file_path}: {e}")
            return file_path
    return file_path

# %%
# Run the function for all .docx and .cha files in the reference_path
for file in os.listdir(reference_path):
    file_path = reference_path / file
    if file_path.is_file() and file_path.suffix.lower() in ['.docx', '.cha']:
        convert_docx_or_cha_to_txt(file_path)
# Out:
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf001_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf002_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf003_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf006_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\bf008_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\bf009_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf010_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf012_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf014_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf015_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf020_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf023_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf026_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf033_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf034_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf035_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf042_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf044_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf046_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf047_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf049_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf050_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf061_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf062_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf063_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf064_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf066_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf068_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf069_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf070_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf071_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf072_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf073_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf074_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf075_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\BF076_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf091_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf092_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf094_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf095_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf096_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf126_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf127_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf133_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf134_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf135_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf136_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf137_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf138_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\BF143_NAp_transkrypcja_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf148_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf149_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf212_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf216_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf224_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf226_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf227_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf235_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\BF237_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf238_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf248_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf249_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf403_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm004_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm005_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm010_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm015_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm016_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm020_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm021_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm022_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm023_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm025_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm028_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm037_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm038_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm044_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm062_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm063_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm068_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm069_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm070_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm078_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm079_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm080_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm120_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm126_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm128_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm132_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm133_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm135_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\BM136_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm137_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm138_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm139_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm215_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm216_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm225_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm236_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm402_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm403_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf009_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf015_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf016_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf033_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf034_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf035_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf037_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf038_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf041_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf071_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf088_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf096_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf097_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf099_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf108_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf109_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf110_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf111_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf113_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf115_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf116_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf117_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf118_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf119_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf120_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf121_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf122_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf124_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf132_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf133_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf800_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf801_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf802_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf806_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf808_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf809_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm008_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm009_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm010_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm066_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm087_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm089_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm092_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm108_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm109_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm110_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm111_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm113_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm114_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm116_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm117_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm118_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm119_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm121_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm800_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm801_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm802_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm803_NAp_transkrypcja_clean.docx
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm804_NAp_transkrypcja_clean.docx

# %% [markdown]
# ### Cleaning the reference files

# %%
# Cleaning the files in the reference_path

def clean_transcript_file(file_path):
    """
    Cleans transcript files by:
    - Removing all lines before the first *CHI: or *EXP:
    - Removing all lines starting with %com: anywhere in the file
    - Removing trailing empty lines and lines like '@End' or similar markers at the end
    Overwrites the file in place.
    """
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Find the index of the first line starting with *CHI: or *EXP:
    start_idx = next(
        (i for i, line in enumerate(lines) if line.lstrip().startswith("*CHI:") or line.lstrip().startswith("*EXP:")),
        None
    )

    if start_idx is not None:
        # Remove %com: lines after trimming the start
        cleaned_lines = [
            line for line in lines[start_idx:]
            if not line.lstrip().startswith("%com:")
        ]
        # Remove trailing empty lines and lines like '@End'
        while cleaned_lines and (cleaned_lines[-1].strip() == "" or cleaned_lines[-1].strip().lower() == "@end"):
            cleaned_lines.pop()
        with open(file_path, 'w', encoding='utf-8') as f:
            f.writelines(cleaned_lines)
        print(f"Cleaned: {file_path}")
    else:
        print(f"No *CHI: or *EXP: found in {file_path}")

# %%
# Running the cleaning function for all .txt files in the reference_path
reference_path = pathlib.Path().resolve() / "czyszczone_transkrypcje"
for file in os.listdir(reference_path):
    file_path = reference_path / file
    if file_path.is_file() and file_path.suffix.lower() == '.txt':
        clean_transcript_file(file_path)
# Out:
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf001_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf002_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf003_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf006_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\bf008_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\bf009_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf010_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf012_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf014_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf015_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf020_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf023_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf026_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf033_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf034_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf035_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf042_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf044_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf046_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf047_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf049_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf050_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf061_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf062_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf063_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf064_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf066_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf068_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf069_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf070_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf071_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf072_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf073_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf074_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf075_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\BF076_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf091_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf092_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf094_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf095_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf096_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf126_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf127_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf133_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf134_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf135_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf136_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf137_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf138_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\BF143_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf148_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf149_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf212_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf216_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf224_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf226_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf227_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf235_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\BF237_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf238_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf248_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf249_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bf403_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm004_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm005_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm010_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm015_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm016_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm020_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm021_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm022_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm023_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm025_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm028_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm037_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm038_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm044_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm062_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm063_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm068_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm069_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm070_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm078_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm079_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm080_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm120_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm126_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm128_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm132_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm133_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm135_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\BM136_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm137_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm138_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm139_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm215_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm216_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm225_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm236_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm402_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Bm403_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf009_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf015_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf016_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf033_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf034_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf035_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf037_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf038_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf041_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf071_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf088_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf096_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf097_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf099_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf108_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf109_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf110_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf111_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf113_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf115_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf116_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf117_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf118_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf119_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf120_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf121_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf122_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf124_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf132_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf133_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf800_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf801_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf802_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf806_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf808_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mf809_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm008_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm009_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm010_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm066_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm087_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm089_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm092_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm108_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm109_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm110_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm111_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm113_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm114_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm116_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm117_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm118_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm119_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm121_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm800_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm801_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm802_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm803_NAp_transkrypcja_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\czyszczone_transkrypcje\Mm804_NAp_transkrypcja_clean.txt

# %% [markdown]
# ## Preprocessing the hypothesis_path

# %% [markdown]
# ### Converting the hypothesis files to .txt

# %%
# converting all files in the hypothesis_path to a .txt format

def convert_cha_to_txt(file_path):
    """
    
    # !!!!!
    Remember to have the backup of the original files before running this function, as it will delete the original files after conversion
    # !!!!!

    Converts .cha files to .txt format and deletes the original file.


    """
    if file_path.suffix.lower() == '.cha':
        new_file_path = file_path.with_suffix('.txt')
        try:
            with open(file_path, 'r', encoding='utf-8') as f_in:
                content = f_in.read()
            with open(new_file_path, 'w', encoding='utf-8') as f_out:
                f_out.write(content)
            os.remove(file_path)
            print(f"Converted and removed: {file_path}")
            return new_file_path
        except Exception as e:
            print(f"Error converting {file_path}: {e}")
            return file_path
    return file_path

# %%
# Run the function for all .cha files in the hypothesis_path
for file in os.listdir(hypothesis_path):
    file_path = hypothesis_path / file
    if file_path.is_file() and file_path.suffix.lower() == '.cha':
        convert_cha_to_txt(file_path)
# Out:
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf012_NAp_сlean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf0134_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf0137_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf0148_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf062_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf063_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf068_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf069_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf074_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf075_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf076_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf133_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf135_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf136_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf212_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf224_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf226_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf227_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf235_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf237_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf238_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf249_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf403_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm004_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm010_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm015_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm016_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm020_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm025_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm028_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm038_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm062_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm063_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm068_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm069_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm080_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm120_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm126_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm135_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm136_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm137_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm138_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm139_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm215_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm216_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm225_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm236_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm402_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm403_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Kopia Bf012_NAp.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf009_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf015_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf016_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf033_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf034_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf035_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf037_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf038_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf041_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf071_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf088_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf097_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf099_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf109_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf110_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf111_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf113_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf115_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf116_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf117_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf118_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf119_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf121_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf122_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf124_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf132_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf133_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf800_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf802_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm008_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm009_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm010_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm066_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm087_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm089_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm092_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm108_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm109_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm111_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm114_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm116_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm117_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm118_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm119_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm121_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm800_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm801_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm802_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm803_NAp_clean.cha
# Converted and removed: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm804_NAp_clean.cha

# %% [markdown]
# ### Cleaning the hypothesis files

# %%
def clean_hypothesis_file(file_path):
    """
    Cleans hypothesis files by:
    - Removing all lines before the first line starting with *PAR (e.g., *PAR0:, *PAR1:, etc.)
    - Removing all timestamp patterns ->  XXXX_XXXX
    - Removing the last line if it is '@End' (case-insensitive) and any trailing empty lines
    Overwrites the file in place.
    """
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Find the index of the first line starting with *PAR
    start_idx = next(
        (i for i, line in enumerate(lines) if line.lstrip().startswith("*PAR")),
        None
    )

    if start_idx is not None:
        cleaned_lines = lines[start_idx:]
        # Remove timestamp patterns
        cleaned_lines = [re.sub(r"\x15\d+_\d+\x15", "", line) for line in cleaned_lines]
        
        
        # Remove trailing lines that are empty or '@End'
        while cleaned_lines and (cleaned_lines[-1].strip() == "" or cleaned_lines[-1].strip().lower() == "@end"):
            cleaned_lines.pop()
        with open(file_path, 'w', encoding='utf-8') as f:
            f.writelines(cleaned_lines)
        print(f"Cleaned: {file_path}")
    else:
        print(f"No *PAR found in {file_path}")

# %%
# Running the cleaning function for all .txt files in the hypothesis_path
hypothesis_path = pathlib.Path().resolve() / "transkrypty_czyszczonych_nagrań"
for file in os.listdir(hypothesis_path):
    file_path = hypothesis_path / file
    if file_path.is_file() and file_path.suffix.lower() == '.txt':
        clean_hypothesis_file(file_path)
# Out:
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf012_NAp_сlean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf0134_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf0137_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf0148_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf062_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf063_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf068_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf069_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf074_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf075_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf076_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf133_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf135_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf136_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf212_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf224_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf226_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf227_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf235_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf237_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf238_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf249_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bf403_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm004_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm010_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm015_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm016_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm020_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm025_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm028_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm038_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm062_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm063_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm068_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm069_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm080_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm120_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm126_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm135_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm136_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm137_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm138_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm139_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm215_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm216_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm225_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm236_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm402_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Bm403_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Kopia Bf012_NAp.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf009_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf015_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf016_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf033_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf034_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf035_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf037_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf038_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf041_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf071_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf088_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf097_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf099_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf109_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf110_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf111_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf113_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf115_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf116_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf117_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf118_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf119_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf121_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf122_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf124_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf132_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf133_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf800_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mf802_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm008_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm009_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm010_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm066_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm087_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm089_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm092_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm108_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm109_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm111_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm114_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm116_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm117_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm118_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm119_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm121_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm800_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm801_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm802_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm803_NAp_clean.txt
# Cleaned: D:\GitHub\Repos\Narracje-ASR\transkrypty_czyszczonych_nagrań\Mm804_NAp_clean.txt

# %% [markdown]
# # Data analysis

# %% [markdown]
# ## Data transformation

# %%
#transformation pipeline

transforms = jiwer.Compose(
    [
        jiwer.ExpandCommonEnglishContractions(), #expands common English contractions like "don't" to "do not"
        jiwer.RemoveEmptyStrings(), #removes empty strings
        jiwer.ToLowerCase(), #converts all characters to lowercase
        jiwer.RemoveMultipleSpaces(), #removes multiple spaces between words
        jiwer.Strip(), #removes leading and trailing spaces
        jiwer.RemovePunctuation(), #removes punctuation marks (e.g., ., !, ?, etc.)
        #jiwer.RemoveKaldiNonWords(), #removes Kaldi non-words (e.g., <unk>, <s>, </s>, etc.)
        jiwer.ReduceToListOfListOfWords(), #reduces the transcription to a list of lists of words
    ]
)

# %%
# List all .txt files in both folders
ref_files = [f for f in os.listdir(reference_path) if f.endswith('.txt')]
hyp_files = [f for f in os.listdir(hypothesis_path) if f.endswith('.txt')]

def extract_key(filename):
    # Match 2 letters, 3 or 4 digits, underscore, NAp (e.g., Ab123_NAp or Ab1234_NAp)
    match = re.match(r"^[A-Za-z]{2}\d{3,4}_NAp", filename)
    if match:
        return match.group(0)
    return filename  # fallback: whole filename if not matched

df_ref = pd.DataFrame({
    'key': [extract_key(f) for f in ref_files],
    'ref_file': ref_files
})
df_hyp = pd.DataFrame({
    'key': [extract_key(f) for f in hyp_files],
    'hyp_file': hyp_files
})

# Merge to get only matching pairs
df = pd.merge(df_ref, df_hyp, on='key')

display(df)
# Out:
#           key                          ref_file             hyp_file
# 0   Bf012_NAp  Bf012_NAp_transkrypcja_clean.txt  Bf012_NAp_сlean.txt
# 1   Bf062_NAp  Bf062_NAp_transkrypcja_clean.txt  Bf062_NAp_clean.txt
# 2   Bf063_NAp  Bf063_NAp_transkrypcja_clean.txt  Bf063_NAp_clean.txt
# 3   Bf068_NAp  Bf068_NAp_transkrypcja_clean.txt  Bf068_NAp_clean.txt
# 4   Bf069_NAp  Bf069_NAp_transkrypcja_clean.txt  Bf069_NAp_clean.txt
# ..        ...                               ...                  ...
# 88  Mm800_NAp  Mm800_NAp_transkrypcja_clean.txt  Mm800_NAp_clean.txt
# 89  Mm801_NAp  Mm801_NAp_transkrypcja_clean.txt  Mm801_NAp_clean.txt
# 90  Mm802_NAp  Mm802_NAp_transkrypcja_clean.txt  Mm802_NAp_clean.txt
# 91  Mm803_NAp  Mm803_NAp_transkrypcja_clean.txt  Mm803_NAp_clean.txt
# 92  Mm804_NAp  Mm804_NAp_transkrypcja_clean.txt  Mm804_NAp_clean.txt
#
# [93 rows x 3 columns]

# %%
#adding string columns to the DataFrame
df['ref_string'] = df['ref_file'].apply(lambda x: (reference_path / x).read_text(encoding='utf-8'))
df['hyp_string'] = df['hyp_file'].apply(lambda x: (hypothesis_path / x).read_text(encoding='utf-8'))

# %%
df
# Out:
#           key                          ref_file             hyp_file  \
# 0   Bf012_NAp  Bf012_NAp_transkrypcja_clean.txt  Bf012_NAp_сlean.txt
# 1   Bf062_NAp  Bf062_NAp_transkrypcja_clean.txt  Bf062_NAp_clean.txt
# 2   Bf063_NAp  Bf063_NAp_transkrypcja_clean.txt  Bf063_NAp_clean.txt
# 3   Bf068_NAp  Bf068_NAp_transkrypcja_clean.txt  Bf068_NAp_clean.txt
# 4   Bf069_NAp  Bf069_NAp_transkrypcja_clean.txt  Bf069_NAp_clean.txt
# ..        ...                               ...                  ...
# 88  Mm800_NAp  Mm800_NAp_transkrypcja_clean.txt  Mm800_NAp_clean.txt
# 89  Mm801_NAp  Mm801_NAp_transkrypcja_clean.txt  Mm801_NAp_clean.txt
# 90  Mm802_NAp  Mm802_NAp_transkrypcja_clean.txt  Mm802_NAp_clean.txt
# 91  Mm803_NAp  Mm803_NAp_transkrypcja_clean.txt  Mm803_NAp_clean.txt
# 92  Mm804_NAp  Mm804_NAp_transkrypcja_clean.txt  Mm804_NAp_clean.txt
#
#                                            ref_string  \
# 0   *EXP:\tdobra Bf012.\n*EXP:\tjuż gotowa?\n*EXP:...
# 1   *EXP:\tdobrze.\n*EXP:\tja nazywam się Lucyna, ...
# 2   *EXP:\tja nazywam się Lucyna.\n*EXP:\tty nazyw...
# 3   *EXP:\tLiliana.\n*EXP:\ttwój numer to be ef ze...
# 4   *EXP:\tpopatrz, mam tutaj trzy koperty.\n*EXP:...
# ..                                                ...
# 88  *CHI:\tTen…\n*CHI:\tYy, w układanki?\n*EXP:\tY...
# 89  *EXP:\tDobra.\n*EXP:\tDobra.\n*EXP:\tTy jesteś...
# 90  *EXP:\tNie, to będzie tylko mikrofon, o.\n*EXP...
# 91  *CHI:\tDługopis?\n*EXP:\tTak.\n*EXP:\tTy jeste...
# 92  *CHI:\tA jak ja mówię, to muszę być tak.\n*CHI...
#
#                                            hyp_string
# 0   *PAR1:\tDobrze . \n*PAR0:\tJuż . \n*PAR1:\tGot...
# 1   *PAR1:\tDobrze ja nazywam się Lucyna i ty . \n...
# 2   *PAR1:\tJa nazywam się Lucyna i Ty nazywasz si...
# 3   *PAR1:\tJa nazywam się Lucyna Jachacy , a Ty n...
# 4   *PAR1:\tJa nazywam się Lucena Jahacy , a ty ? ...
# ..                                                ...
# 88  *PAR0:\tJak tam powie +... \n*PAR0:\tPoczekaj ...
# 89  *PAR0:\tDobra , ty jesteś Edward , MM801 . \n*...
# 90  *PAR0:\tTak , i ty jesteś Mateusz , MM802 . \n...
# 91  *PAR0:\tKamera i mikrofon . \n*PAR0:\tMam indy...
# 92  *PAR1:\tBeniamin MM804 . \n*PAR2:\tBeniamin . ...
#
# [93 rows x 5 columns]

# %%
#applying the transformation pipeline to the strings in the DataFrame
df['ref_transformed'] = df['ref_string'].apply(lambda x: " ".join(sum(transforms(x), [])))
df['hyp_transformed'] = df['hyp_string'].apply(lambda x: " ".join(sum(transforms(x), [])))

# %%
df
# Out:
#           key                          ref_file             hyp_file  \
# 0   Bf012_NAp  Bf012_NAp_transkrypcja_clean.txt  Bf012_NAp_сlean.txt
# 1   Bf062_NAp  Bf062_NAp_transkrypcja_clean.txt  Bf062_NAp_clean.txt
# 2   Bf063_NAp  Bf063_NAp_transkrypcja_clean.txt  Bf063_NAp_clean.txt
# 3   Bf068_NAp  Bf068_NAp_transkrypcja_clean.txt  Bf068_NAp_clean.txt
# 4   Bf069_NAp  Bf069_NAp_transkrypcja_clean.txt  Bf069_NAp_clean.txt
# ..        ...                               ...                  ...
# 88  Mm800_NAp  Mm800_NAp_transkrypcja_clean.txt  Mm800_NAp_clean.txt
# 89  Mm801_NAp  Mm801_NAp_transkrypcja_clean.txt  Mm801_NAp_clean.txt
# 90  Mm802_NAp  Mm802_NAp_transkrypcja_clean.txt  Mm802_NAp_clean.txt
# 91  Mm803_NAp  Mm803_NAp_transkrypcja_clean.txt  Mm803_NAp_clean.txt
# 92  Mm804_NAp  Mm804_NAp_transkrypcja_clean.txt  Mm804_NAp_clean.txt
#
#                                            ref_string  \
# 0   *EXP:\tdobra Bf012.\n*EXP:\tjuż gotowa?\n*EXP:...
# 1   *EXP:\tdobrze.\n*EXP:\tja nazywam się Lucyna, ...
# 2   *EXP:\tja nazywam się Lucyna.\n*EXP:\tty nazyw...
# 3   *EXP:\tLiliana.\n*EXP:\ttwój numer to be ef ze...
# 4   *EXP:\tpopatrz, mam tutaj trzy koperty.\n*EXP:...
# ..                                                ...
# 88  *CHI:\tTen…\n*CHI:\tYy, w układanki?\n*EXP:\tY...
# 89  *EXP:\tDobra.\n*EXP:\tDobra.\n*EXP:\tTy jesteś...
# 90  *EXP:\tNie, to będzie tylko mikrofon, o.\n*EXP...
# 91  *CHI:\tDługopis?\n*EXP:\tTak.\n*EXP:\tTy jeste...
# 92  *CHI:\tA jak ja mówię, to muszę być tak.\n*CHI...
#
#                                            hyp_string  \
# 0   *PAR1:\tDobrze . \n*PAR0:\tJuż . \n*PAR1:\tGot...
# 1   *PAR1:\tDobrze ja nazywam się Lucyna i ty . \n...
# 2   *PAR1:\tJa nazywam się Lucyna i Ty nazywasz si...
# 3   *PAR1:\tJa nazywam się Lucyna Jachacy , a Ty n...
# 4   *PAR1:\tJa nazywam się Lucena Jahacy , a ty ? ...
# ..                                                ...
# 88  *PAR0:\tJak tam powie +... \n*PAR0:\tPoczekaj ...
# 89  *PAR0:\tDobra , ty jesteś Edward , MM801 . \n*...
# 90  *PAR0:\tTak , i ty jesteś Mateusz , MM802 . \n...
# 91  *PAR0:\tKamera i mikrofon . \n*PAR0:\tMam indy...
# 92  *PAR1:\tBeniamin MM804 . \n*PAR2:\tBeniamin . ...
#
#                                       ref_transformed  \
# 0   exp\tdobra bf012\nexp\tjuż gotowa\nexp\tto jes...
# 1   exp\tdobrze\nexp\tja nazywam się lucyna ty naz...
# 2   exp\tja nazywam się lucyna\nexp\tty nazywasz s...
# 3   exp\tliliana\nexp\ttwój numer to be ef zero sz...
# 4   exp\tpopatrz mam tutaj trzy koperty\nexp\tsą w...
# ..                                                ...
# 88  chi\tten\nchi\tyy w układanki\nexp\tyy\nchi\tc...
# 89  exp\tdobra\nexp\tdobra\nexp\tty jesteś edward ...
# 90  exp\tnie to będzie tylko mikrofon o\nexp\ttak\...
# 91  chi\tdługopis\nexp\ttak\nexp\tty jesteś paweł ...
# 92  chi\ta jak ja mówię to muszę być tak\nchi\twow...
#
#                                       hyp_transformed
# 0   par1\tdobrze par0\tjuż par1\tgotowa par1\tdobr...
# 1   par1\tdobrze ja nazywam się lucyna i ty par0\t...
# 2   par1\tja nazywam się lucyna i ty nazywasz się ...
# 3   par1\tja nazywam się lucyna jachacy a ty nazyw...
# 4   par1\tja nazywam się lucena jahacy a ty par1\t...
# ..                                                ...
# 88  par0\tjak tam powie + par0\tpoczekaj par1\tbol...
# 89  par0\tdobra ty jesteś edward mm801 par0\tja pa...
# 90  par0\ttak i ty jesteś mateusz mm802 par0\tdobr...
# 91  par0\tkamera i mikrofon par0\tmam indyko pis p...
# 92  par1\tbeniamin mm804 par2\tbeniamin par1\tbeni...
#
# [93 rows x 7 columns]

# %%
# Calculate WER and CER for each pair after transformation
results = []
for _, row in df.iterrows():
    with open(reference_path / row['ref_file'], encoding='utf-8') as f:
        ref_text = f.read()
    with open(hypothesis_path / row['hyp_file'], encoding='utf-8') as f:
        hyp_text = f.read()
    # Apply the transformation pipeline
    ref_transformed = " ".join(sum(transforms(ref_text), []))
    hyp_transformed = " ".join(sum(transforms(hyp_text), []))
    results.append({
        'key': row['key'],
        'ref_file': row['ref_file'],
        'hyp_file': row['hyp_file'],
        'WER': jiwer.wer(ref_transformed, hyp_transformed),
        'CER': jiwer.cer(ref_transformed, hyp_transformed),
        'WIL': jiwer.wil(ref_transformed, hyp_transformed),
        'MER': jiwer.mer(ref_transformed, hyp_transformed),
        'WIP': jiwer.wip(ref_transformed, hyp_transformed)
    })

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#           key                          ref_file             hyp_file  \
# 0   Bf012_NAp  Bf012_NAp_transkrypcja_clean.txt  Bf012_NAp_сlean.txt
# 1   Bf062_NAp  Bf062_NAp_transkrypcja_clean.txt  Bf062_NAp_clean.txt
# 2   Bf063_NAp  Bf063_NAp_transkrypcja_clean.txt  Bf063_NAp_clean.txt
# 3   Bf068_NAp  Bf068_NAp_transkrypcja_clean.txt  Bf068_NAp_clean.txt
# 4   Bf069_NAp  Bf069_NAp_transkrypcja_clean.txt  Bf069_NAp_clean.txt
# ..        ...                               ...                  ...
# 88  Mm800_NAp  Mm800_NAp_transkrypcja_clean.txt  Mm800_NAp_clean.txt
# 89  Mm801_NAp  Mm801_NAp_transkrypcja_clean.txt  Mm801_NAp_clean.txt
# 90  Mm802_NAp  Mm802_NAp_transkrypcja_clean.txt  Mm802_NAp_clean.txt
# 91  Mm803_NAp  Mm803_NAp_transkrypcja_clean.txt  Mm803_NAp_clean.txt
# 92  Mm804_NAp  Mm804_NAp_transkrypcja_clean.txt  Mm804_NAp_clean.txt
#
#          WER       CER       WIL       MER       WIP
# 0   0.558712  0.330821  0.628787  0.462745  0.371213
# 1   0.646137  0.411369  0.786211  0.573559  0.213789
# 2   0.553473  0.303480  0.673902  0.487852  0.326098
# 3   0.663446  0.352302  0.736375  0.541393  0.263625
# 4   0.837681  0.569810  0.776484  0.615548  0.223516
# ..       ...       ...       ...       ...       ...
# 88  0.545302  0.291371  0.625194  0.450763  0.374806
# 89  0.744681  0.504256  0.802824  0.618971  0.197176
# 90  0.602990  0.331856  0.665657  0.487248  0.334343
# 91  0.628407  0.337551  0.692963  0.506944  0.307037
# 92  0.539095  0.307596  0.643075  0.458042  0.356925
#
# [93 rows x 8 columns]

# %%
# calculating mean metrics

mean_metrics = results_df[['WER', 'CER', 'WIL', 'MER', 'WIP']].mean().to_frame(name='Mean').reset_index()
mean_metrics.columns = ['Metric', 'Mean']
print(mean_metrics)
# Out:
#   Metric      Mean
# 0    WER  0.712054
# 1    CER  0.467787
# 2    WIL  0.696625
# 3    MER  0.527852
# 4    WIP  0.303375
